# %% [markdown]
# ## Shortening Evaluation

# %%
import os
os.environ['http_proxy'] = 'http://192.41.170.23:3128'
os.environ['https_proxy'] = 'http://192.41.170.23:3128'
import sys         
sys.path.append('/home/pranisaa/working_dir/Text-Summarization')
from config import *
from score import  RougeScore, BertScore
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
params = model_params
def get_rouge(params, method, quantity, data, epoch):
    path = f"""../model/t5-small_{data}_{method}_{quantity}_{epoch}epochs/"""
    rougescore = RougeScore(model = params["MODEL"], dataset = data, EPOCH = epoch, path = path)
    rougescores = rougescore.getscore_ave()
    return rougescores

def get_bert(params, method, quantity, data, epoch):
    path = f"""../model/t5-small_{data}_{method}_{quantity}_{epoch}epochs/"""
    bertscore = BertScore(model = params["MODEL"], dataset = data, EPOCH = epoch, path = path)
    bertscores = bertscore.getscore()
    return bertscores

# %% [markdown]
# #### Fine-tuned for 50 epochs

# %%
rougescores_fulltext = get_rouge(params, "full-text", 0, 'xsum', 50)
rougescores_head25 = get_rouge(params, "head-only", 25, 'xsum', 50)
rougescores_head35 = get_rouge(params, "head-only", 35, 'xsum', 50)
rougescores_head45 = get_rouge(params, "head-only", 45, 'xsum', 50)
rougescores_tail25 = get_rouge(params, "tail-only", 25, 'xsum', 50)
rougescores_tail35 = get_rouge(params, "tail-only", 35, 'xsum', 50)
rougescores_tail45 = get_rouge(params, "tail-only", 45, 'xsum', 50)
rougescores_headtail_02_25 = get_rouge(params, "head+tail_ratio0.2", 25, 'xsum', 50)
rougescores_headtail_02_35 = get_rouge(params, "head+tail_ratio0.2", 35, 'xsum', 50)
rougescores_headtail_02_45 = get_rouge(params, "head+tail_ratio0.2", 45, 'xsum', 50)
rougescores_headtail_05_25 = get_rouge(params, "head+tail_ratio0.5", 25, 'xsum', 50)
rougescores_headtail_05_35 = get_rouge(params, "head+tail_ratio0.5", 35, 'xsum', 50)
rougescores_headtail_05_45 = get_rouge(params, "head+tail_ratio0.5", 45, 'xsum', 50)
rougescores_luhn25 = get_rouge(params, "luhn", 25, 'xsum', 50)
rougescores_luhn35 = get_rouge(params, "luhn", 35, 'xsum', 50)
rougescores_luhn45 = get_rouge(params, "luhn", 45, 'xsum', 50)
rougescores_textrank25 = get_rouge(params, "textrank", 25, 'xsum', 50)
rougescores_textrank35 = get_rouge(params, "textrank", 35, 'xsum', 50)
rougescores_textrank45 = get_rouge(params, "textrank", 45, 'xsum', 50)
rougescores_lsa25 = get_rouge(params, "lsa", 25, 'xsum', 50)
rougescores_lsa35 = get_rouge(params, "lsa", 35, 'xsum', 50)
rougescores_lsa45 = get_rouge(params, "lsa", 45, 'xsum', 50)
rougescores_stopwords_all = get_rouge(params, "stopwords", 'all', 'xsum', 50)
rougescores_stopwords_neg = get_rouge(params, "stopwords", 'neg', 'xsum', 50)
rougescores_stopwords_neg_headtail_05_25 = get_rouge(params, "stopwords_neg", 'head+tail_ratio0.5_25', 'xsum', 50)
rougescores_stopwords_neg_headtail_05_35 = get_rouge(params, "stopwords_neg", 'head+tail_ratio0.5_35', 'xsum', 50)
rougescores_stopwords_neg_headtail_05_45 = get_rouge(params, "stopwords_neg", 'head+tail_ratio0.5_45', 'xsum', 50)
rougescores_stopwords_neg_headtail_02_25 = get_rouge(params, "combo_stopwords_neg", 'head+tail_ratio0.2_25', 'xsum', 50)
rougescores_stopwords_neg_headtail_02_35 = get_rouge(params, "combo_stopwords_neg", 'head+tail_ratio0.2_35', 'xsum', 50)
rougescores_stopwords_neg_headtail_02_45 = get_rouge(params, "combo_stopwords_neg", 'head+tail_ratio0.2_45', 'xsum', 50)
rougescores_stopwords_neg_textrank_25 = get_rouge(params, "combo_stopwords_neg", 'textrank_25', 'xsum', 50)
rougescores_stopwords_neg_textrank_35 = get_rouge(params, "combo_stopwords_neg", 'textrank_35', 'xsum', 50)
rougescores_stopwords_neg_textrank_45 = get_rouge(params, "combo_stopwords_neg", 'textrank_45', 'xsum', 50)
rougescores_stopwords_neg_luhn_25 = get_rouge(params, "combo_stopwords_neg", 'luhn_25', 'xsum', 50)
rougescores_stopwords_neg_luhn_35 = get_rouge(params, "combo_stopwords_neg", 'luhn_35', 'xsum', 50)
rougescores_stopwords_neg_luhn_45 = get_rouge(params, "combo_stopwords_neg", 'luhn_45', 'xsum', 50)
rougescores_stopwords_all_textrank_25 = get_rouge(params, "combo_stopwords_all", 'textrank_25', 'xsum', 50)
rougescores_stopwords_all_textrank_35 = get_rouge(params, "combo_stopwords_all", 'textrank_35', 'xsum', 50)
rougescores_stopwords_all_textrank_45 = get_rouge(params, "combo_stopwords_all", 'textrank_45', 'xsum', 50)
rougescores_stopwords_all_luhn_25 = get_rouge(params, "combo_stopwords_all", 'luhn_25', 'xsum', 50)
rougescores_stopwords_all_luhn_35 = get_rouge(params, "combo_stopwords_all", 'luhn_35', 'xsum', 50)
rougescores_stopwords_all_luhn_45 = get_rouge(params, "combo_stopwords_all", 'luhn_45', 'xsum', 50)

# %% [markdown]
# #### Compare All Strategies Rouge Scores

# %%
rouge_head_onlys = {"plots": [rougescores_fulltext, rougescores_head25, rougescores_head35, rougescores_head45], "labels" : ['full-text', 'head-only_25', 'head-only_35', 'head-only_45']}
rouge_tail_onlys = {"plots": [rougescores_fulltext, rougescores_tail25, rougescores_tail35, rougescores_tail45], "labels" : ['full-text', 'tail-only_25', 'tail-only_35', 'tail-only_45']}
rouge_headtail_r02s = {"plots": [rougescores_fulltext, rougescores_headtail_02_25, rougescores_headtail_02_35, rougescores_headtail_02_45], "labels" : ['full-text', 'head+tail_r0.2_25', 'head+tail_r0.2_35', 'head+tail_r0.2_45']}
rouge_headtail_r05s = {"plots": [rougescores_fulltext, rougescores_headtail_05_25, rougescores_headtail_05_35, rougescores_headtail_05_45], "labels" : ['full-text', 'head+tail_r0.5_25', 'head+tail_r0.5_35', 'head+tail_r0.5_45']}
rouge_luhns = {"plots": [rougescores_fulltext, rougescores_luhn25, rougescores_luhn35, rougescores_luhn45], "labels" : ['full-text', 'luhn_25', 'luhn_35', 'luhn_45']}
rouge_textranks = {"plots": [rougescores_fulltext, rougescores_textrank25, rougescores_textrank35, rougescores_textrank45], "labels" : ['full-text', 'textrank25', 'textrank35', "textrank45"]}
rouge_lsas = {"plots": [rougescores_fulltext, rougescores_lsa25, rougescores_lsa35, rougescores_lsa45], "labels" : ['full-text', 'lsa25', 'lsa35',"lsa45" ]}
rouge_stopwords = {"plots": [rougescores_fulltext, rougescores_stopwords_all, rougescores_stopwords_neg], "labels" : ['full-text', 'stopwords_all', 'stopwords_neg', ]}
rouge_stopwords_neg_headtail_r05s = {"plots": [rougescores_fulltext, rougescores_stopwords_neg_headtail_05_25,rougescores_stopwords_neg_headtail_05_35, rougescores_stopwords_neg_headtail_05_45], \
                                 "labels": ['full-text', 'stopwords_neg_headtailr05_25', 'stopwords_neg_headtailr05_35', 'stopwords_neg_headtailr05_45' ]}
rouge_stopwords_neg_headtail_r02s = {"plots": [rougescores_fulltext, rougescores_stopwords_neg_headtail_02_25,rougescores_stopwords_neg_headtail_02_35, rougescores_stopwords_neg_headtail_05_45], \
                                 "labels": ['full-text', 'stopwords_neg_headtailr02_25', 'stopwords_neg_headtailr02_35', 'stopwords_neg_headtailr05_45' ]}
rouge_stopwords_neg_textranks = {"plots": [rougescores_fulltext, rougescores_stopwords_neg_textrank_25,rougescores_stopwords_neg_textrank_35, rougescores_stopwords_neg_textrank_45], \
                                 "labels": ['full-text', 'stopwords_neg_textrank_25', 'stopwords_neg_textrank_35', 'stopwords_neg_textrank_45' ]}
rouge_stopwords_neg_luhns = {"plots": [rougescores_fulltext, rougescores_stopwords_neg_luhn_25,rougescores_stopwords_neg_luhn_35, rougescores_stopwords_neg_luhn_45], \
                                 "labels": ['full-text', 'stopwords_neg_luhn_25', 'stopwords_neg_luhn_35', 'stopwords_neg_luhn_45' ]}
rouge_stopwords_all_textranks = {"plots": [rougescores_fulltext, rougescores_stopwords_all_textrank_25 ,rougescores_stopwords_all_textrank_35, rougescores_stopwords_all_textrank_45], \
                                 "labels": ['full-text', 'stopwords_all_textrank_25', 'stopwords_all_textrank_35', 'stopwords_all_textrank_45' ]}
rouge_stopwords_all_luhns = {"plots": [rougescores_fulltext, rougescores_stopwords_all_luhn_25,rougescores_stopwords_all_luhn_35, rougescores_stopwords_all_luhn_45], \
                                 "labels": ['full-text', 'stopwords_all_luhn_25', 'stopwords_all_luhn_35', 'stopwords_all_luhn_45' ]}

# %%
# rougescores_lsa45, "lsa45"
fig, axs = plt.subplots(4, 4, figsize=(40,25))
for i, plot in enumerate(rouge_head_onlys["plots"]):
    axs[0, 0].plot(plot['rouge1'], label = rouge_head_onlys["labels"][i])
    axs[0, 0].set_title("Compare Head-onlys Rouge")
    axs[0, 0].set_ylim([12.5, 30])
    axs[0, 0].legend()
for i, plot in enumerate(rouge_tail_onlys["plots"]):
    axs[0, 1].plot(plot['rouge1'], label = rouge_tail_onlys["labels"][i])
    axs[0, 1].set_title("Compare Tail-onlys Rouge")
    axs[0, 1].set_ylim([12.5, 30])
    axs[0, 1].legend()
for i, plot in enumerate(rouge_headtail_r02s["plots"]):
    axs[0, 2].plot(plot['rouge1'], label = rouge_headtail_r02s["labels"][i])
    axs[0, 2].set_title("Compare HeadTail 0.2 Rouge")
    axs[0, 2].set_ylim([12.5, 30])
    axs[0, 2].legend()
for i, plot in enumerate(rouge_headtail_r05s["plots"]):
    axs[0, 3].plot(plot['rouge1'], label = rouge_headtail_r05s["labels"][i])
    axs[0, 3].set_title("Compare HeadTail 0.5 Rouge")
    axs[0, 3].set_ylim([12.5, 30])
    axs[0, 3].legend()
for i, plot in enumerate(rouge_luhns["plots"]):
    axs[1, 0].plot(plot['rouge1'], label = rouge_luhns["labels"][i])
    axs[1, 0].set_title("Compare Luhns")
    axs[1, 0].set_ylim([12.5, 30])
    axs[1, 0].legend()
for i, plot in enumerate(rouge_textranks["plots"]):
    axs[1, 1].plot(plot['rouge1'], label = rouge_textranks["labels"][i])
    axs[1, 1].set_title("Compare Textrank")
    axs[1, 1].set_ylim([12.5, 30])
    axs[1, 1].legend()
for i, plot in enumerate(rouge_lsas["plots"]):
    axs[1, 2].plot(plot['rouge1'], label = rouge_lsas["labels"][i])
    axs[1, 2].set_title("Compare LSA")
    axs[1, 2].set_ylim([12.5, 30])
    axs[1, 2].legend()
for i, plot in enumerate(rouge_stopwords["plots"]):
    axs[1, 3].plot(plot['rouge1'], label = rouge_stopwords["labels"][i])
    axs[1, 3].set_title("Compare Stopwords")
    axs[1, 3].set_ylim([12.5, 30])
    axs[1, 3].legend()
for i, plot in enumerate(rouge_stopwords_neg_headtail_r05s["plots"]):
    axs[2, 0].plot(plot['rouge1'], label = rouge_stopwords_neg_headtail_r05s["labels"][i])
    axs[2, 0].set_title("Compare Stopwords Neg Headtail 0.5 Rouge")
    axs[2, 0].set_ylim([12.5, 30])
    axs[2, 0].legend()
for i, plot in enumerate(rouge_stopwords_neg_headtail_r02s["plots"]):
    axs[2, 1].plot(plot['rouge1'], label = rouge_stopwords_neg_headtail_r02s["labels"][i])
    axs[2, 1].set_title("Compare Stopwords Neg Headtail 0.2 Rouge")
    axs[2, 1].set_ylim([12.5, 30])
    axs[2, 1].legend()
for i, plot in enumerate(rouge_stopwords_neg_textranks["plots"]):
    axs[3, 0].plot(plot['rouge1'], label = rouge_stopwords_neg_textranks["labels"][i])
    axs[3, 0].set_title("Compare Stopwords Neg Textrank Rouge")
    axs[3, 0].set_ylim([12.5, 30])
    axs[3, 0].legend()
for i, plot in enumerate(rouge_stopwords_neg_luhns["plots"]):
    axs[3, 1].plot(plot['rouge1'], label = rouge_stopwords_neg_luhns["labels"][i])
    axs[3, 1].set_title("Compare Stopwords Neg Luhn Rouge")
    axs[3, 1].set_ylim([12.5, 30])
    axs[3, 1].legend()
for i, plot in enumerate(rouge_stopwords_all_textranks["plots"]):
    axs[3, 2].plot(plot['rouge1'], label = rouge_stopwords_all_textranks["labels"][i])
    axs[3, 2].set_title("Compare Stopwords All Textrank Rouge")
    axs[3, 2].set_ylim([12.5, 30])
    axs[3, 2].legend()
for i, plot in enumerate(rouge_stopwords_all_luhns["plots"]):
    axs[3, 3].plot(plot['rouge1'], label = rouge_stopwords_all_luhns["labels"][i])
    axs[3, 3].set_title("Compare Stopwords All Luhn Rouge")
    axs[3, 3].set_ylim([12.5, 30])
    axs[3, 3].legend()
# axs[1, 1].scatter(x, y)

# %% [markdown]
# #### Compare Strategies of Each Quantity

# %%
fig, axs = plt.subplots(1, 3, figsize=(20,4))
quantity_25 = {"plots": [rougescores_fulltext, rougescores_head25, rougescores_tail25, 
                         rougescores_headtail_02_25, rougescores_headtail_05_25, 
                         rougescores_luhn25, rougescores_textrank25, rougescores_lsa25, 
                         rougescores_stopwords_neg_headtail_05_25,
                         rougescores_stopwords_neg_headtail_02_25,
                         rougescores_stopwords_neg_textrank_25,
                         rougescores_stopwords_neg_luhn_25,
                         rougescores_stopwords_all_textrank_25,
                         rougescores_stopwords_all_luhn_25], 
               "labels" : ['full-text', 'head-only_25', 'tail-only_25', 'headtail_r0.2_25', 
                           'headtail_r0.5_25', 'luhn_25', 'textrank_25', 'lsa_25', 
                           'stopword_headtail_r50_25', 'stopword_headtail_r20_25',
                           'stopword_neg_textrank_25', 'stopword_neg_luhn_25',
                           'stopword_all_textrank_25', 'stopword_all_luhn_25'],}
quantity_35 = {"plots": [rougescores_fulltext, rougescores_head35, rougescores_tail35, 
                         rougescores_headtail_02_35, rougescores_headtail_05_35, 
                         rougescores_luhn35, rougescores_textrank35, rougescores_lsa35,
                         rougescores_stopwords_neg_headtail_05_35,
                         rougescores_stopwords_neg_headtail_02_35,
                         rougescores_stopwords_neg_textrank_35,
                         rougescores_stopwords_neg_luhn_35,
                         rougescores_stopwords_all_textrank_35,
                         rougescores_stopwords_all_luhn_35], 
               "labels" : ['full-text', 'head-only_35', 'tail-only_35', 'headtail_r0.2_35', 
                           'headtail_r0.5_35', 'luhn_35', 'textrank_35',  'lsa_35',
                           'stopword_headtail_r50_35', 'stopword_headtail_r20_35',
                           'stopword_textrank_35', 'stopword_neg_luhn_35',
                           'stopword_all_textrank_35', 'stopword_all_luhn_35'],}
quantity_45 = {"plots": [rougescores_fulltext, rougescores_head45, rougescores_tail45, 
                         rougescores_headtail_02_45, rougescores_headtail_05_45, 
                         rougescores_luhn45, rougescores_textrank45, rougescores_lsa45,
                         rougescores_stopwords_neg_headtail_05_45,
                         rougescores_stopwords_neg_headtail_02_45,
                        rougescores_stopwords_neg_textrank_45,
                         rougescores_stopwords_neg_luhn_45,
                         rougescores_stopwords_all_textrank_45,
                         rougescores_stopwords_all_luhn_45], 
               "labels" : ['full-text', 'head-only_45', 'tail-only_45', 'headtail_r0.2_45', 
                           'headtail_r0.5_45', 'luhn_45', 'textrank_45', 'lsa_45', 
                           'stopword_headtail_r50_45', 'stopword_headtail_r20_45',
                           'stopword_textrank_45', 'stopword_neg_luhn_45',
                           'stopword_all_textrank_45', 'stopword_all_luhn_45'],}
for i, plot in enumerate(quantity_25["plots"]):
    axs[0].plot(plot['rouge1'], label = quantity_25["labels"][i]) #, linestyle = quantity_25["linestyles"][i])
    axs[0].set_title("Compare Quantity 25")
    axs[0].legend()
for i, plot in enumerate(quantity_35["plots"]):
    axs[1].plot(plot['rouge1'], label = quantity_35["labels"][i])
    axs[1].set_title("Compare Quantity 35")
    axs[1].legend()
for i, plot in enumerate(quantity_45["plots"]):
    axs[2].plot(plot['rouge1'], label = quantity_45["labels"][i])
    axs[2].set_title("Compare Quantity 45")
    axs[2].legend()

# %%
def prep_barplot(quantity, score = 'rouge1', mode = "lastepoch"):
    if mode == "lastepoch":
        scores = [ q[score][-1] for q in quantity['plots']]
    else:
        scores = [ max(q[score]) for q in quantity['plots']]
    lables = [ l for l in quantity['labels']]
    return scores, lables

fig, axs = plt.subplots(2, 4, figsize=(28, 10), constrained_layout = True)
quantity_25_scores, quantity_25_lables = prep_barplot(quantity_25, 'rouge1')
ax00 = axs[0, 0].bar(quantity_25_lables, quantity_25_scores)
axs[0, 0].set_xticklabels(quantity_25_lables, rotation=25)
axs[0, 0].set_title("Compare RougeScore1 of EPOCH 50")
axs[0, 0].legend()
axs[0, 0].bar_label(ax00, padding=3, label_type= 'center', fmt ='%.3g')

quantity_35_scores, quantity_35_lables = prep_barplot(quantity_35, 'rouge1')
ax01 = axs[0, 1].bar(quantity_35_lables, quantity_35_scores)
axs[0, 1].set_xticklabels(quantity_35_lables, rotation=25)
axs[0, 1].set_title("Compare RougeScore1 of EPOCH 50")
axs[0, 1].legend()
axs[0, 1].bar_label(ax01, padding=3, label_type= 'center', fmt ='%.3g')

quantity_45_scores, quantity_45_lables = prep_barplot(quantity_45, 'rouge1')
ax02 = axs[0, 2].bar(quantity_45_lables, quantity_45_scores)
axs[0, 2].set_xticklabels(quantity_45_lables, rotation=25)
axs[0, 2].set_title("Compare RougeScore1 of EPOCH 50")
axs[0, 2].legend()
axs[0, 2].bar_label(ax02, padding=3, label_type= 'center', fmt ='%.3g')

fig, axs = plt.subplots(2, 4, figsize=(28, 10), constrained_layout = True)

quantity_25_scores, quantity_25_lables = prep_barplot(quantity_25, 'rouge1', 'best')
ax00 = axs[0, 0].bar(quantity_25_lables, quantity_25_scores)
axs[0, 0].set_xticklabels(quantity_25_lables, rotation=25)
axs[0, 0].set_title("Compare RougeScore1 of EPOCH 50")
# axs[0, 0].legend()
axs[0, 0].bar_label(ax00, padding=3, label_type= 'center', fmt ='%.3g')

quantity_35_scores, quantity_35_lables = prep_barplot(quantity_35, 'rouge1', 'best')
ax01 = axs[0, 1].bar(quantity_35_lables, quantity_35_scores)
axs[0, 1].set_xticklabels(quantity_35_lables, rotation=25)
axs[0, 1].set_title("Compare RougeScore1 of EPOCH 50")
axs[0, 1].legend()
axs[0, 1].bar_label(ax01, padding=3, label_type= 'center', fmt ='%.3g')

quantity_45_scores, quantity_45_lables = prep_barplot(quantity_45, 'rouge1', 'best')
ax02 = axs[0, 2].bar(quantity_45_lables, quantity_45_scores)
axs[0, 2].set_xticklabels(quantity_45_lables, rotation=25)
axs[0, 2].set_title("Compare RougeScore1 of EPOCH 50")
axs[0, 2].legend()
axs[0, 2].bar_label(ax02, padding=3, label_type= 'center', fmt ='%.3g')
# Out:
# /tmp/ipykernel_357369/1068319682.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0, 0].set_xticklabels(quantity_25_lables, rotation=25)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# /tmp/ipykernel_357369/1068319682.py:19: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0, 1].set_xticklabels(quantity_35_lables, rotation=25)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# /tmp/ipykernel_357369/1068319682.py:26: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0, 2].set_xticklabels(quantity_45_lables, rotation=25)
# ...

# %%
fig, axs = plt.subplots(2, 4, figsize=(28, 10), constrained_layout = True)

quantity_25_scores, quantity_25_lables = prep_barplot(quantity_25, 'rouge2')
ax00 = axs[0, 0].bar(quantity_25_lables, quantity_25_scores)
axs[0, 0].set_xticklabels(quantity_25_lables, rotation=25)
axs[0, 0].set_title("Compare RougeScore2 of EPOCH 50")
axs[0, 0].legend()
axs[0, 0].bar_label(ax00, padding=3, label_type= 'center', fmt ='%.3g')

quantity_35_scores, quantity_35_lables = prep_barplot(quantity_35, 'rouge2')
ax01 = axs[0, 1].bar(quantity_35_lables, quantity_35_scores)
axs[0, 1].set_xticklabels(quantity_35_lables, rotation=25)
axs[0, 1].set_title("Compare RougeScore2 of EPOCH 50")
axs[0, 1].legend()
axs[0, 1].bar_label(ax01, padding=3, label_type= 'center', fmt ='%.3g')

quantity_45_scores, quantity_45_lables = prep_barplot(quantity_45, 'rouge2')
ax02 = axs[0, 2].bar(quantity_45_lables, quantity_45_scores)
axs[0, 2].set_xticklabels(quantity_45_lables, rotation=25)
axs[0, 2].set_title("Compare RougeScore2 of EPOCH 50")
axs[0, 2].legend()
axs[0, 2].bar_label(ax02, padding=3, label_type= 'center', fmt ='%.3g')

fig, axs = plt.subplots(2, 4, figsize=(28, 10), constrained_layout = True)

quantity_25_scores, quantity_25_lables = prep_barplot(quantity_25, 'rouge2', 'best')
ax00 = axs[0, 0].bar(quantity_25_lables, quantity_25_scores)
axs[0, 0].set_xticklabels(quantity_25_lables, rotation=25)
axs[0, 0].set_title("Compare RougeScore1 of EPOCH 50")
axs[0, 0].legend()
axs[0, 0].bar_label(ax00, padding=3, label_type= 'center', fmt ='%.3g')

quantity_35_scores, quantity_35_lables = prep_barplot(quantity_35, 'rouge2', 'best')
ax01 = axs[0, 1].bar(quantity_35_lables, quantity_35_scores)
axs[0, 1].set_xticklabels(quantity_35_lables, rotation=25)
axs[0, 1].set_title("Compare RougeScore1 of EPOCH 50")
axs[0, 1].legend()
axs[0, 1].bar_label(ax01, padding=3, label_type= 'center', fmt ='%.3g')

quantity_45_scores, quantity_45_lables = prep_barplot(quantity_45, 'rouge2', 'best')
ax02 = axs[0, 2].bar(quantity_45_lables, quantity_45_scores)
axs[0, 2].set_xticklabels(quantity_45_lables, rotation=25)
axs[0, 2].set_title("Compare RougeScore1 of EPOCH 50")
axs[0, 2].legend()
axs[0, 2].bar_label(ax02, padding=3, label_type= 'center', fmt ='%.3g')
# Out:
# /tmp/ipykernel_357369/2687541757.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0, 0].set_xticklabels(quantity_25_lables, rotation=25)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# /tmp/ipykernel_357369/2687541757.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0, 1].set_xticklabels(quantity_35_lables, rotation=25)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# /tmp/ipykernel_357369/2687541757.py:19: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0, 2].set_xticklabels(quantity_45_lables, rotation=25)
# ...

# %%
fig, axs = plt.subplots(2, 4, figsize=(28, 10), constrained_layout = True)

quantity_25_scores, quantity_25_lables = prep_barplot(quantity_25, 'rougeL')
ax00 = axs[0, 0].bar(quantity_25_lables, quantity_25_scores)
axs[0, 0].set_xticklabels(quantity_25_lables, rotation=25)
axs[0, 0].set_title("Compare RougeScoreL of EPOCH 50")
axs[0, 0].legend()
axs[0, 0].bar_label(ax00, padding=3, label_type= 'center', fmt ='%.3g')

quantity_35_scores, quantity_35_lables = prep_barplot(quantity_35, 'rougeL')
ax01 = axs[0, 1].bar(quantity_35_lables, quantity_35_scores)
axs[0, 1].set_xticklabels(quantity_35_lables, rotation=25)
axs[0, 1].set_title("Compare RougeScoreL of EPOCH 50")
axs[0, 1].legend()
axs[0, 1].bar_label(ax01, padding=3, label_type= 'center', fmt ='%.3g')

quantity_45_scores, quantity_45_lables = prep_barplot(quantity_45, 'rougeL')
ax02 = axs[0, 2].bar(quantity_45_lables, quantity_45_scores)
axs[0, 2].set_xticklabels(quantity_45_lables, rotation=25)
axs[0, 2].set_title("Compare RougeScoreL of EPOCH 50")
axs[0, 2].legend()
axs[0, 2].bar_label(ax02, padding=3, label_type= 'center', fmt ='%.3g')

fig, axs = plt.subplots(2, 4, figsize=(28, 10), constrained_layout = True)

quantity_25_scores, quantity_25_lables = prep_barplot(quantity_25, 'rougeL', 'best')
ax00 = axs[0, 0].bar(quantity_25_lables, quantity_25_scores)
axs[0, 0].set_xticklabels(quantity_25_lables, rotation=25)
axs[0, 0].set_title("Compare RougeScore1 of EPOCH 50")
axs[0, 0].legend()
axs[0, 0].bar_label(ax00, padding=3, label_type= 'center', fmt ='%.3g')

quantity_35_scores, quantity_35_lables = prep_barplot(quantity_35, 'rougeL', 'best')
ax01 = axs[0, 1].bar(quantity_35_lables, quantity_35_scores)
axs[0, 1].set_xticklabels(quantity_35_lables, rotation=25)
axs[0, 1].set_title("Compare RougeScore1 of EPOCH 50")
axs[0, 1].legend()
axs[0, 1].bar_label(ax01, padding=3, label_type= 'center', fmt ='%.3g')

quantity_45_scores, quantity_45_lables = prep_barplot(quantity_45, 'rougeL', 'best')
ax02 = axs[0, 2].bar(quantity_45_lables, quantity_45_scores)
axs[0, 2].set_xticklabels(quantity_45_lables, rotation=25)
axs[0, 2].set_title("Compare RougeScore1 of EPOCH 50")
axs[0, 2].legend()
axs[0, 2].bar_label(ax02, padding=3, label_type= 'center', fmt ='%.3g')
# Out:
# /tmp/ipykernel_357369/1003152532.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0, 0].set_xticklabels(quantity_25_lables, rotation=25)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# /tmp/ipykernel_357369/1003152532.py:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0, 1].set_xticklabels(quantity_35_lables, rotation=25)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# /tmp/ipykernel_357369/1003152532.py:19: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axs[0, 2].set_xticklabels(quantity_45_lables, rotation=25)
# ...

# %%
quantity_45_scores
# Out:
# [22.2737,
#  21.5602,
#  19.4042,
#  20.1739,
#  20.8566,
#  21.1664,
#  20.4013,
#  19.7504,
#  20.2131,
#  19.7507,
#  21.0117,
#  21.0117,
#  20.2835,
#  20.8556]

# %%
quantity_45_lables
# Out:
# ['full-text',
#  'head-only_35',
#  'tail-only_35',
#  'headtail_r0.2_35',
#  'headtail_r0.5_35',
#  'luhn_35',
#  'textrank_35',
#  'lsa_35',
#  'stopword_headtail_r50_35',
#  'stopword_headtail_r20_35',
#  'stopword_textrank_35',
#  'stopword_neg_luhn_35',
#  'stopword_all_textrank_35',
#  'stopword_all_luhn_35']

# %%
# EPOCH = 30
# model = 't5-small'
# path = f"""../model/{model_params["MODEL"]}_{data}_full-text/"""
# def dev(n):
#     scores = []
#     for epoch in range(EPOCH):
#         path_df = os.path.join(path, f"result_eval/predictions_{model}_epoch{epoch}.csv")
#         df = pd.read_csv(path_df)
#         _id = df['Sample ids'][n]
#         scores.append(df['RougeScore1'][df['Sample ids']==_id])
#     return scores

# fig = plt.figure(figsize=(25, 20))
# fig.subplots_adjust(hspace=0.8, wspace=0.8)

# for n in range(0,100):
#     ax = fig.add_subplot(10, 10, n + 1)
#     scores = dev(n)
#     ax.plot(scores)
#     ax.text(30, 35, str(np.round(np.mean(scores),2)),
#          fontsize=14, weight = 'medium', ha='right', va = 'bottom')
#     ax.set_ylim([0,50])
